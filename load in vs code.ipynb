# %% [markdown]
# Практическая работа №5 - Анализ датасета

# %% [markdown]
# Цель: Реализовать базовый анализ датасета, включающий вывод всех уникальных значений, сортировку по определенным параметрам, удаление ненужных столбцов и строк, замену определенных значений, удаление дубликатов, проведение анализа с использованием функций info и describe, выборку данных по строкам и столбцам с помощью loc, а также сохранение нового датасета.

# %% [markdown]
# Описание датасета Terraria: NAME - НАЗВАНИЕ ПРЕДМЕТОВ, CLASS - КЛАСС ПЕРСОНАЖА, GAME PROGRESSION - ПРОГРЕСС ИГРЫ, DPS (SINGLE TARGET) - УРОР ПО ОДИНОЧНОЙ ЦЕЛИ, DPS (MULTI TARGET) - УРОН ПО МНОГОЦЕЛЕВОЙ, DPS (SINGLE TARGET + PROYECTILE ONLY) - УРОН ТОЛЬКО ОДИНОЧНОЙ ЦЕЛИ + СНАРЯД, DPS (MULTI TARGET + PROYECTILE ONLY) - УРОН ТОЛЬКО ДЛЯ НЕСКОЛЬКИХ ЦЕЛЕЙ + СНАРЯД, OBSERVATIONS - НАБЛЮДЕНИЕ

# %%
import pandas as pd
import numpy as np
Terraria = pd.read_csv("Terraria.csv")
Terraria
# Out:
#                    NAME     CLASS GAME PROGRESSION  DPS (SINGLE TARGET)  \
# 0                Zenith     Melee    Post-Moonlord                 4800
# 1            Last Prism      Mage    Post-Moonlord                 3657
# 2            Star Wrath     Melee    Post-Moonlord                 2700
# 3             Terrarian     Melee    Post-Moonlord                 2200
# 4              Meowmere     Melee    Post-Moonlord                 2100
# ..                  ...       ...              ...                  ...
# 390         Paper Plane    Ranger         Pre-Boss                   14
# 391         Finch Staff  Summoner         Pre-Boss                   10
# 392      Flameburst Rod  Summoner         Pre-Boss                    8
# 393         Flinx Staff  Summoner         Pre-Boss                    8
# 394  Lightning Aura Rod  Summoner         Pre-Boss                    8
#
#      DPS (MULTI TARGET)  DPS (SINGLE TARGET + PROYECTILE ONLY)  \
# 0               13000.0                                    NaN
# 1                1142.0                                    NaN
# 2                5800.0                                 1500.0
# 3                4600.0                                  700.0
# 4                6400.0                                 1300.0
# ..                  ...                                    ...
# 390                 NaN                                    NaN
# 391                25.0                                    NaN
# 392                18.0                                    NaN
# 393                70.0                                    NaN
# 394                24.0                                    NaN
#
#      DPS (MULTI TARGET + PROYECTILE ONLY)      OBSERVATIONS
# 0                                     NaN               NaN
# 1                                     NaN     Fully charged
# 2                                  3700.0               NaN
# 3                                  1000.0               NaN
# 4                                  3400.0               NaN
# ..                                    ...               ...
# 390                                   NaN   Does not pierce
# 391                                   NaN               NaN
# 392                                   NaN  Only two dummies
# 393                                   NaN               NaN
# 394                                   NaN               NaN
#
# [395 rows x 8 columns]

# %% [markdown]
# Этап 2: После этого требуется вывести данные с использованием команды вашдатасет.head().

# %%
Terraria.head()
# Out:
#          NAME  CLASS GAME PROGRESSION  DPS (SINGLE TARGET)  \
# 0      Zenith  Melee    Post-Moonlord                 4800
# 1  Last Prism   Mage    Post-Moonlord                 3657
# 2  Star Wrath  Melee    Post-Moonlord                 2700
# 3   Terrarian  Melee    Post-Moonlord                 2200
# 4    Meowmere  Melee    Post-Moonlord                 2100
#
#    DPS (MULTI TARGET)  DPS (SINGLE TARGET + PROYECTILE ONLY)  \
# 0             13000.0                                    NaN
# 1              1142.0                                    NaN
# 2              5800.0                                 1500.0
# 3              4600.0                                  700.0
# 4              6400.0                                 1300.0
#
#    DPS (MULTI TARGET + PROYECTILE ONLY)   OBSERVATIONS
# 0                                   NaN            NaN
# 1                                   NaN  Fully charged
# 2                                3700.0            NaN
# 3                                1000.0            NaN
# 4                                3400.0            NaN

# %% [markdown]
# Этап 3: Затем необходимо отобразить размерность массива, используя вашдатасет.shape.

# %%
Terraria.shape
# Out:
# (395, 8)

# %% [markdown]
# Этап 4: Далее требуется вывести наименование всех колонок, написать что они означают в нашем датасете с помощью .columns

# %%
Terraria.columns
# Out:
# Index(['NAME', 'CLASS', 'GAME PROGRESSION', 'DPS (SINGLE TARGET)',
#        'DPS (MULTI TARGET)', 'DPS (SINGLE TARGET + PROYECTILE ONLY)',
#        'DPS (MULTI TARGET + PROYECTILE ONLY)', 'OBSERVATIONS'],
#       dtype='object')

# %% [markdown]
# Этап 5: Затем необходимо вывести все уникальные значения с помощью .unique

# %%
Terraria['CLASS'].unique()
# Out:
# array(['Melee', 'Mage', 'Ranger', 'Summoner'], dtype=object)

# %% [markdown]
# Этап 6: Далле нужно сделать сортировку по определенным параметрам с помощью .sort_values

# %%
Terraria.sort_values(by='DPS (SINGLE TARGET)')
# Out:
#                    NAME     CLASS GAME PROGRESSION  DPS (SINGLE TARGET)  \
# 394  Lightning Aura Rod  Summoner         Pre-Boss                    8
# 393         Flinx Staff  Summoner         Pre-Boss                    8
# 392      Flameburst Rod  Summoner         Pre-Boss                    8
# 391         Finch Staff  Summoner         Pre-Boss                   10
# 390         Paper Plane    Ranger         Pre-Boss                   14
# ..                  ...       ...              ...                  ...
# 4              Meowmere     Melee    Post-Moonlord                 2100
# 3             Terrarian     Melee    Post-Moonlord                 2200
# 2            Star Wrath     Melee    Post-Moonlord                 2700
# 1            Last Prism      Mage    Post-Moonlord                 3657
# 0                Zenith     Melee    Post-Moonlord                 4800
#
#      DPS (MULTI TARGET)  DPS (SINGLE TARGET + PROYECTILE ONLY)  \
# 394                24.0                                    NaN
# 393                70.0                                    NaN
# 392                18.0                                    NaN
# 391                25.0                                    NaN
# 390                 NaN                                    NaN
# ..                  ...                                    ...
# 4                6400.0                                 1300.0
# 3                4600.0                                  700.0
# 2                5800.0                                 1500.0
# 1                1142.0                                    NaN
# 0               13000.0                                    NaN
#
#      DPS (MULTI TARGET + PROYECTILE ONLY)      OBSERVATIONS
# 394                                   NaN               NaN
# 393                                   NaN               NaN
# 392                                   NaN  Only two dummies
# 391                                   NaN               NaN
# 390                                   NaN   Does not pierce
# ..                                    ...               ...
# 4                                  3400.0               NaN
# 3                                  1000.0               NaN
# 2                                  3700.0               NaN
# 1                                     NaN     Fully charged
# 0                                     NaN               NaN
#
# [395 rows x 8 columns]

# %% [markdown]
# Этап 7: Затем необходимо выполнить удаление ненужных столбцов или строк с помощью .drop

# %%
Terraria.drop(columns = ["OBSERVATIONS"], inplace=True)

# %% [markdown]
# Этап 8: Далее нужно заменить определенные значения в датасете (например, пустые) с помошью .replace

# %%
Terraria["GAME PROGRESSION"] = Terraria["GAME PROGRESSION"].replace(Terraria["GAME PROGRESSION"].unique(), "Unknown")
Terraria
# Out:
#                    NAME     CLASS GAME PROGRESSION  DPS (SINGLE TARGET)  \
# 0                Zenith     Melee          Unknown                 4800
# 1            Last Prism      Mage          Unknown                 3657
# 2            Star Wrath     Melee          Unknown                 2700
# 3             Terrarian     Melee          Unknown                 2200
# 4              Meowmere     Melee          Unknown                 2100
# ..                  ...       ...              ...                  ...
# 390         Paper Plane    Ranger          Unknown                   14
# 391         Finch Staff  Summoner          Unknown                   10
# 392      Flameburst Rod  Summoner          Unknown                    8
# 393         Flinx Staff  Summoner          Unknown                    8
# 394  Lightning Aura Rod  Summoner          Unknown                    8
#
#      DPS (MULTI TARGET)  DPS (SINGLE TARGET + PROYECTILE ONLY)  \
# 0               13000.0                                    NaN
# 1                1142.0                                    NaN
# 2                5800.0                                 1500.0
# 3                4600.0                                  700.0
# 4                6400.0                                 1300.0
# ..                  ...                                    ...
# 390                 NaN                                    NaN
# 391                25.0                                    NaN
# 392                18.0                                    NaN
# 393                70.0                                    NaN
# 394                24.0                                    NaN
#
#      DPS (MULTI TARGET + PROYECTILE ONLY)
# 0                                     NaN
# 1                                     NaN
# 2                                  3700.0
# 3                                  1000.0
# 4                                  3400.0
# ..                                    ...
# 390                                   NaN
# 391                                   NaN
# 392                                   NaN
# 393                                   NaN
# 394                                   NaN
#
# [395 rows x 7 columns]

# %% [markdown]
# Этап 9: Затем необходимо выполнить удаление дубликатов с помощью .drop_duplicates()

# %%
Terraria = Terraria.drop_duplicates()
Terraria
# Out:
#                    NAME     CLASS GAME PROGRESSION  DPS (SINGLE TARGET)  \
# 0                Zenith     Melee          Unknown                 4800
# 1            Last Prism      Mage          Unknown                 3657
# 2            Star Wrath     Melee          Unknown                 2700
# 3             Terrarian     Melee          Unknown                 2200
# 4              Meowmere     Melee          Unknown                 2100
# ..                  ...       ...              ...                  ...
# 390         Paper Plane    Ranger          Unknown                   14
# 391         Finch Staff  Summoner          Unknown                   10
# 392      Flameburst Rod  Summoner          Unknown                    8
# 393         Flinx Staff  Summoner          Unknown                    8
# 394  Lightning Aura Rod  Summoner          Unknown                    8
#
#      DPS (MULTI TARGET)  DPS (SINGLE TARGET + PROYECTILE ONLY)  \
# 0               13000.0                                    NaN
# 1                1142.0                                    NaN
# 2                5800.0                                 1500.0
# 3                4600.0                                  700.0
# 4                6400.0                                 1300.0
# ..                  ...                                    ...
# 390                 NaN                                    NaN
# 391                25.0                                    NaN
# 392                18.0                                    NaN
# 393                70.0                                    NaN
# 394                24.0                                    NaN
#
#      DPS (MULTI TARGET + PROYECTILE ONLY)
# 0                                     NaN
# 1                                     NaN
# 2                                  3700.0
# 3                                  1000.0
# 4                                  3400.0
# ..                                    ...
# 390                                   NaN
# 391                                   NaN
# 392                                   NaN
# 393                                   NaN
# 394                                   NaN
#
# [395 rows x 7 columns]

# %% [markdown]
# Этап 10: Далее нужно провести анализ с помощью функций .describe()

# %%
Terraria.describe()
# Out:
#        DPS (SINGLE TARGET)  DPS (MULTI TARGET)  \
# count           395.000000          309.000000
# mean            262.273418          651.543689
# std             437.778258         1102.016874
# min               8.000000           17.000000
# 25%              58.000000          150.000000
# 50%             130.000000          350.000000
# 75%             289.000000          771.000000
# max            4800.000000        13000.000000
#
#        DPS (SINGLE TARGET + PROYECTILE ONLY)  \
# count                              25.000000
# mean                              348.600000
# std                               380.502738
# min                                30.000000
# 25%                                80.000000
# 50%                               250.000000
# 75%                               500.000000
# max                              1500.000000
#
#        DPS (MULTI TARGET + PROYECTILE ONLY)
# count                             19.000000
# mean                             961.315789
# std                             1036.653057
# min                               75.000000
# 25%                              250.000000
# 50%                              650.000000
# 75%                             1050.000000
# max                             3700.000000

# %% [markdown]
# Этап 11: Затем необходимо Провести выборку данных по строкам и столбцам с помощью .loc

# %%
subset = Terraria.loc[[0, 1, 2], ['NAME', 'CLASS']]
subset
# Out:
#          NAME  CLASS
# 0      Zenith  Melee
# 1  Last Prism   Mage
# 2  Star Wrath  Melee

# %% [markdown]
# Этап 12: Далее нужно Провести анализ с помощью функций .info()

# %%
Terraria.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 395 entries, 0 to 394
# Data columns (total 8 columns):
#  #   Column                                 Non-Null Count  Dtype
# ---  ------                                 --------------  -----
#  0   NAME                                   395 non-null    object
#  1   CLASS                                  395 non-null    object
#  2   GAME PROGRESSION                       395 non-null    object
#  3   DPS (SINGLE TARGET)                    395 non-null    int64
#  4   DPS (MULTI TARGET)                     309 non-null    float64
#  5   DPS (SINGLE TARGET + PROYECTILE ONLY)  25 non-null     float64
#  6   DPS (MULTI TARGET + PROYECTILE ONLY)   19 non-null     float64
#  7   OBSERVATIONS                           395 non-null    object
# dtypes: float64(3), int64(1), object(4)
# memory usage: 24.8+ KB

# %% [markdown]
# Финальный этап: Необходимо сохранить наш датасет с помощью .to_csv и написать в конце нужный индекс. Если он False то не будет сохранен, а если True то он сохраниться

# %%
Terraria.to_csv("Terraria_clear.csv", index=True)
Terraria
# Out:
#                    NAME     CLASS GAME PROGRESSION  DPS (SINGLE TARGET)  \
# 0                Zenith     Melee          Unknown                 4800
# 1            Last Prism      Mage          Unknown                 3657
# 2            Star Wrath     Melee          Unknown                 2700
# 3             Terrarian     Melee          Unknown                 2200
# 4              Meowmere     Melee          Unknown                 2100
# ..                  ...       ...              ...                  ...
# 390         Paper Plane    Ranger          Unknown                   14
# 391         Finch Staff  Summoner          Unknown                   10
# 392      Flameburst Rod  Summoner          Unknown                    8
# 393         Flinx Staff  Summoner          Unknown                    8
# 394  Lightning Aura Rod  Summoner          Unknown                    8
#
#      DPS (MULTI TARGET)  DPS (SINGLE TARGET + PROYECTILE ONLY)  \
# 0               13000.0                                    NaN
# 1                1142.0                                    NaN
# 2                5800.0                                 1500.0
# 3                4600.0                                  700.0
# 4                6400.0                                 1300.0
# ..                  ...                                    ...
# 390                 NaN                                    NaN
# 391                25.0                                    NaN
# 392                18.0                                    NaN
# 393                70.0                                    NaN
# 394                24.0                                    NaN
#
#      DPS (MULTI TARGET + PROYECTILE ONLY)
# 0                                     NaN
# 1                                     NaN
# 2                                  3700.0
# 3                                  1000.0
# 4                                  3400.0
# ..                                    ...
# 390                                   NaN
# 391                                   NaN
# 392                                   NaN
# 393                                   NaN
# 394                                   NaN
#
# [395 rows x 7 columns]

# %% [markdown]
# Вывод: Мы осуществили базовый анализ датасета, включая вывод уникальных значений, сортировку по определенным параметрам, удаление лишних столбцов и строк, замену определенных значений, исключение дубликатов, анализ при помощи функций info и describe, выборку данных через loc по определенным строкам и столбцам, а также сохранение измененного датасета.
